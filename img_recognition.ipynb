# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjana3705/image-recognition/blob/main/img_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python-headless
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=b13fae67422bd989af7750382bd7366ef478a661487869bfb2945143aedf59ae
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import cv2
import os
from google.colab import drive
from google.colab import files

# Mount Google Drive
drive.mount('/content/drive')

# Function to load images and corresponding labels from a folder
def load_images_from_folder(folder):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert image to grayscale
        images.append(img)
        labels.append(os.path.splitext(filename)[0])
    return images, labels

# Function to recognize faces in a new image
def recognize_faces(new_image, known_images, known_labels):
    # Implementation of face recognition goes here
    pass

# Define the path to the folder containing your images in Google Drive
folder_path = "/content/drive/MyDrive/san"

# Load images and labels from the folder
known_images, known_labels = load_images_from_folder(folder_path)

# Function to upload a photo
def upload_photo():
    uploaded = files.upload()
    for filename in uploaded.keys():
        new_image_path = filename
        new_image = cv2.imread(new_image_path)
        return new_image

# Process the uploaded image
new_image = upload_photo()

if new_image is not None:
    # Recognize faces in the new image
    recognized_person = recognize_faces(new_image, known_images, known_labels)
    print("Recognized person:",recognised person)
else:
    print("No image uploaded.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-eec32d62-70a3-481f-bbf6-139294bf3155" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eec32d62-70a3-481f-bbf6-139294bf3155">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
